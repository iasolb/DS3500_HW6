# %%
import pandas as pd
import numpy as np
from assignta import AssignTa


def test1():
    a = AssignTa()
    a.assign_ta_df("assignta_data/tas.csv")
    a.assign_lab_df("assignta_data/sections.csv")
    a.assignment = (a._load_data("assignta_data/test1")).to_numpy()
    # TODO make a setup with a known assignment matrix
    return a


def main():
    test = test1()
    test
    print(f"Test 1 dtype: {test.dtype()}")
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[1], line 21
#      17     test1
#      18     print(f"Test 1 dtype: {test1.dtype()}")
# ---> 21 main()
#
# Cell In[1], line 16, in main()
#      15 def main():
# ---> 16     test1 = test1()
#      17     test1
#      18     print(f"Test 1 dtype: {test1.dtype()}")
#
# UnboundLocalError: cannot access local variable 'test1' where it is not associated with a value
